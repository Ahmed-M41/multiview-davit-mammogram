# %% [markdown]
# # 01 — Explore CBIS-DDSM Dataset
#
# This notebook explores the CBIS-DDSM dataset structure, class distribution, and metadata.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

from multiview_davit.config import load_config

data_cfg = load_config('configs/data.yaml')
train_csv = Path(data_cfg.cbis_ddsm.train_csv)
test_csv  = Path(data_cfg.cbis_ddsm.test_csv)

# %%
# Load splits
train_df = pd.read_csv(train_csv)
test_df  = pd.read_csv(test_csv)
print(f'Train: {len(train_df)} rows | Test: {len(test_df)} rows')
print(train_df.head())

# %%
# Class distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for ax, (name, df) in zip(axes, [('Train', train_df), ('Test', test_df)]):
    counts = df['cancer'].value_counts().rename({0: 'Benign', 1: 'Malignant'})
    counts.plot.bar(ax=ax, color=['steelblue', 'salmon'])
    ax.set_title(f'{name} — Class Distribution')
    ax.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# View distribution
print('View distribution:')
print(train_df['view'].value_counts())
